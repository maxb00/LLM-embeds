# %% [markdown]
# # Investigating GPT-3 embeddings
# * Load data from text files
# * Assemble data structures
# * Define heplper functions
# * Investigate vectors

# %%
import os
import openai
import numpy as np
from openai.embeddings_utils import get_embedding       # requires plotly
from sklearn.metrics.pairwise import cosine_similarity

# Set in conda
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
# for eng['ada']
# space for other constants
eng = {'ada': 'text-similarity-ada-001', 'bab': 'text-similarity-babbage-001'}

vocab = []
with open(u'/gpfs/fs1/home/mbarlow6/Desktop/Conceptual-Analysis/barlow/valid_vocab.txt', 'r') as f:
    for w in f:
        vocab.append(w.strip())

# %% [markdown]
# ### Model Loading

# %%
# Ada embeds: 1024 dims
ada_embeds = []
with open(u'/gpfs/fs1/home/mbarlow6/Desktop/Conceptual-Analysis/barlow/gpt/gpt_ada.txt', 'r') as f:
    for line in f:
        ada_embeds.append([float(x) for x in line.strip().split()])

model_ada = dict(zip(vocab, ada_embeds))

# %%
# Babbage embeds: 2048 dims
bab_embeds = []
with open(u'/gpfs/fs1/home/mbarlow6/Desktop/Conceptual-Analysis/barlow/gpt/gpt_babbage.txt', 'r') as f:
    for line in f:
        bab_embeds.append([float(x) for x in line.strip().split()])

model_bab = dict(zip(vocab, bab_embeds))

# %% [markdown]
# ### Helper Functions
# * definition -> most_similar, positive
# * calculate_similarity ((a + b) -> t)
# * sum_complexity
# * above_zero_complexity

# %%
def positive(words, model='ada'):
    """
    Given a list of words, sum the embeddings. (matrix addition)
    words: list[str]
    model: str -> ['ada', 'bab']
    """
    if model.lower() == 'ada':
        mdl = model_ada
    elif model.lower() == 'bab':
        mdl = model_bab
    else:
        raise ValueError('Model selection must be \'ada\' or \'bab\'')

    print(words)
    res = np.array(mdl[words[0]]).reshape(1, -1)
    for x in words[1:]:
        res += np.array(mdl[x]).reshape(1, -1)
    return res

# %%
def most_similar(word, phrase=False, top_n=10, model='ada'):
    """
    Return the 10 most similar words to a given word based on BERT embeddings
    word: string
    model: str -> ['ada', 'bab']
    """
    if model.lower() == 'ada':
        mdl = model_ada
    elif model.lower() == 'bab':
        mdl = model_bab
    else:
        raise ValueError('Model selection must be \'ada\' or \'bab\'')

    similarities = {}
    word1 = word
    if not phrase:
        word1 = np.array(mdl[word]).reshape(1, -1)
    for term in vocab:
        word2 = np.array(mdl[term]).reshape(1, -1)
        if isinstance(word, str):
            if term != word:
                similarities[term] = cosine_similarity(word1, word2)
        elif word2.any():
            similarities[term] = cosine_similarity(word1, word2)
    return list({k: v for k, v in sorted(similarities.items(), key=lambda item: item[1], reverse=True)}.items())[2:2+top_n]

# %%
def definition(word1, word2, top_n=10, model='ada'):
    """
    Return top_n most similar words to the positive of two word vectors.
    word1, word2: str
    top_n: int
    model: str -> ['ada', 'bab']
    """
    if model.lower() == 'ada':
        mdl = model_ada
    elif model.lower() == 'bab':
        mdl = model_bab
    else:
        raise ValueError('Model selection must be \'ada\' or \'bab\'')
    
    return most_similar(positive([word1, word2]), True, top_n, model)

# %%
def calculate_similarity(words, target, model='ada'):
    """
    Calculate the similarity between the positive of a list of words and a target
    word1, word2, target: str
    model: str -> ['ada', 'bab']
    """
    if model.lower() == 'ada':
        mdl = model_ada
    elif model.lower() == 'bab':
        mdl = model_bab
    else:
        raise ValueError('Model selection must be \'ada\' or \'bab\'')

    # get the phrase vector
    phrase = positive(words, model)

    # get target vector
    target = np.array(mdl[target]).reshape(1, -1)

    return cosine_similarity(phrase, target)[0][0]

# %%
def calculate_connect(a, b, model='ada'):
    """
    Given two word strings or feature vectors, calcuate their similarity.
    a, b: str | list[float] (or ndarray)
    """
    if model.lower() == 'ada':
        mdl = model_ada
    elif model.lower() == 'bab':
        mdl = model_bab
    else:
        raise ValueError('Model selection must be \'ada\' or \'bab\'')

    if isinstance(a, str):
        a = np.array(mdl[a]).reshape(1, -1)
    
    if isinstance(b, str):
        b = np.array(mdl[b]).reshape(1, -1)

    return cosine_similarity(a, b)[0][0]

# %%
def sum_complexity(word, model='ada'):
    """
    Sums the absolute value of each dimension in a word's embedding vector
    args:
        word: str -> word to get embedding for
    returns:
        sum of absolute value of each dimension in embedding vector
    """
    if model.lower() == 'ada':
        mdl = model_ada
    elif model.lower() == 'bab':
        mdl = model_bab
    else:
        raise ValueError('Model selection must be \'ada\' or \'bab\'')

    # should we keep absolute value here?
    modified = [abs(float(x)) for x in mdl[word]]
    return sum(modified)

# %%
def above_zero_complexity(word, threshold=0.05, model='ada'):
    if model.lower() == 'ada':
        mdl = model_ada
    elif model.lower() == 'bab':
        mdl = model_bab
    else:
        raise ValueError('Model selection must be \'ada\' or \'bab\'')
    
    emb = mdl[word]
    modified = [abs(float(x)) for x in emb if abs(float(x)) > threshold]
    return len(modified) / len(emb)

# %% [markdown]
# ### Vector investigation
#
# What's going on? Initial thoughts are leading me towards the angle of a vector (embedding) point us towards it's component ideas' "meaning space", and it's magnitude reveals something about the strength of connection to that meaning space. Higher magnitudes could mean that a vector is more "embedded" within a certain feature space, which lends validity to single word embeddings having a higher `sum_complexity` than paragraphs with many ideas.
#
# Cosine similarity only scores based on angle, not magnitude, which allows us to easily use positives to approximate combined meaning because we aren't worried about the magnitude of those positives. What if both are important? If complex ideas reside closer to 0 and this is because of their inherent complexity, then we must consider those values signifigant as well. The same argument generalizes to absolute value.
#
# If "apple" represents an idea space, then I would expect a short sentence all about apples to have a strong angle similarity to single word vectors related to apples (fruit, round, etc) and a story about apple picking to have strong angle similarity but small magnitude due to the influence of other major ideas in the story (context).
#
# I will begin to test such ideas below.

# %%
wh = get_embedding('white house', eng['ada'])
bd = get_embedding('baby duck', eng['ada'])
um = get_embedding('unmarried man', eng['ada'])

hw = get_embedding('Hello, world! It is I, the bachelor duckling, come to lay seige to the White House.', eng['ada'])

complaint = get_embedding("These are giving me a headache... It seems like the threshold I choose is statistical, not meaningful. (Are they the same in a model?) Each threshold I choose leaves VERY little space in variation of 'above zero complexity' - when I choose based on quartile all terms score about 0.4. As that term moves closer to 1, we include less and less points, and the complexity scores move with the percentage of data that is being preserved. Bottom 20\% \of numbers are below -0.0218967255204916, and top 20\% \are above 0.024340828508138665, so something like threshold 0.021 captures 40\% \of the data, nearly every time, no matter the word. This doesn't feel conducive to our goal.", eng['ada'])

# %%
save = ""
S = np.inf
for word in vocab:
    x = np.sqrt(sum(np.square(np.array(model_ada[word]))))
    if x < S:
        S = x
        save = word

print(save, S)
# Out:
# slice 0.9999998985397428

# %% [markdown]
# These vectors are already normalized. They all have magnitude of ~1.
#
# The angle holds the meaning, so they give us the angle with all of the magnitude removed (or it never had any?). Either way, I want to know exactly where these vectors come from.
#
# If I follow Tiyanyi's BERT extraction, we are extracting a tensor from the final hidden layer (this tracks) and "collapsing" it to one dimension. I MUST check next if the BERT and GloVe embeddings are unit vectors, or if that is being purposefully removed from my GPT-3 numbers.

# %%
stats = [[-np.inf, np.inf] for _ in range(1024)]
for word in vocab:
    sav = model_ada[word]
    for i in range(len(sav)):
        a = max(sav[i], stats[i][0])
        b = min(sav[i], stats[i][1])
        stats[i] = [a, b]
stats
# Out:
# [[0.0473531112074852, -0.04032731428742409],
#  [0.058770302683115005, -0.02359817735850811],
#  [0.08929447829723358, -0.016218511387705803],
#  [0.058664415031671524, -0.038060858845710754],
#  [0.058821048587560654, -0.03827482834458351],
#  [-0.04090197756886482, -0.09630098938941956],
#  [0.03429153189063072, -0.04687555879354477],
#  [0.047650378197431564, -0.035731248557567596],
#  [0.062188588082790375, -0.016763126477599144],
#  [0.07979156076908112, -0.015510978177189827],
#  [0.062479838728904724, -0.0465640053153038],
#  [0.0768628865480423, -0.04128465801477432],
#  [0.11122137308120728, -0.03664661943912506],
#  [0.04215479642152786, -0.059398237615823746],
#  [0.010684815235435963, -0.07880668342113495],
#  [0.012746586464345455, -0.07621308416128159],
#  [0.05233878269791603, -0.04047093540430069],
#  [0.07791697233915329, -0.00869848020374775],
#  [0.0665426254272461, -0.04140705615282059],
#  [0.06160860136151314, -0.031194813549518585],
#  [0.04382297024130821, -0.05112776160240173],
#  [0.04634447395801544, -0.05840116739273071],
#  [0.10043451935052872, 0.0032513143960386515],
#  [0.05200590193271637, -0.0803784430027008],
#  [0.054598961025476456, -0.03614792972803116],
#  [0.05636248737573624, -0.028372669592499733],
#  [0.028470687568187714, -0.06325072050094604],
#  [0.015831509605050087, -0.07004082202911377],
#  [0.03747934103012085, -0.08915285021066666],
#  [0.01324491947889328, -0.09059791266918182],
#  [0.008105946704745293, -0.07879764586687088],
#  [0.06820899993181229, -0.017424536868929863],
#  [-0.06865126639604568, -0.1877460777759552],
#  [0.06490124762058258, -0.036409005522727966],
#  [0.015724414959549904, -0.07156965136528015],
#  [0.07752719521522522, -0.02316279150545597],
#  [0.07893089205026627, -0.023197956383228302],
#  [0.0687473863363266, -0.02460385672748089],
#  [0.02687818743288517, -0.07876177132129669],
#  [0.015226590447127819, -0.06992930173873901],
#  [0.014795584604144096, -0.06616251170635223],
#  [0.03403642028570175, -0.05979711934924126],
#  [0.05311742424964905, -0.04395117610692978],
#  [0.06237553060054779, -0.02583167888224125],
#  [-0.008517100475728512, -0.09926705807447433],
#  [0.030431240797042847, -0.0471169576048851],
#  [0.06152685359120369, -0.04441293329000473],
#  [0.030080052092671394, -0.0627746507525444],
#  [0.05295077711343765, -0.05187469348311424],
#  [0.059174735099077225, -0.02765585109591484],
#  [0.03795807808637619, -0.07620382308959961],
#  [-0.0035886778496205807, -0.0871373638510704],
#  [0.06339381635189056, -0.03116525523364544],
#  [0.06125960871577263, -0.03240320459008217],
#  [0.04252507537603378, -0.05974159017205238],
#  ...]

# %%
out = {}
for word in vocab:
    similarities = {}
    word1 = np.array(model_ada[word]).reshape(1, -1)
    for term in vocab:
        word2 = np.array(model_ada[term]).reshape(1, -1)
        if isinstance(word, str):
            if term != word:
                similarities[term] = cosine_similarity(-word1, word2)
        elif word2.any():
            similarities[term] = cosine_similarity(-word1, word2)
    out[word] = list({k: v for k, v in sorted(similarities.items(), key=lambda item: item[1], reverse=True)}.items())[:12]
out
# Out:
# {'pop': [('desert', array([[-0.72404487]])),
#   ('if', array([[-0.72592409]])),
#   ('anything', array([[-0.74276688]])),
#   ('neighbourhood', array([[-0.74334324]])),
#   ('counter', array([[-0.74378124]])),
#   ('trading', array([[-0.7509998]])),
#   ('fourth', array([[-0.75196933]])),
#   ('shy', array([[-0.75453149]])),
#   ('nicely', array([[-0.75456093]])),
#   ('full', array([[-0.75486021]])),
#   ('opposition', array([[-0.75492814]])),
#   ('conference', array([[-0.7552774]]))],
#  'data': [('if', array([[-0.70459939]])),
#   ('desert', array([[-0.70670718]])),
#   ('trading', array([[-0.71099037]])),
#   ('counter', array([[-0.71319908]])),
#   ('neighbourhood', array([[-0.72607206]])),
#   ('fourth', array([[-0.72686721]])),
#   ('nephew', array([[-0.73218959]])),
#   ('anything', array([[-0.73219735]])),
#   ('pleasure', array([[-0.73308749]])),
#   ('pale', array([[-0.73312825]])),
#   ('origin', array([[-0.73334271]])),
#   ('smoothly', array([[-0.73363183]]))],
#  'expect': [('convenient', array([[-0.73275913]])),
#   ('desert', array([[-0.73332679]])),
#   ('cinema', array([[-0.74038539]])),
#   ('trading', array([[-0.74386514]])),
#   ('work', array([[-0.74427778]])),
#   ('rank', array([[-0.74500377]])),
#   ('full', array([[-0.74519783]])),
#   ('attraction', array([[-0.74610276]])),
#   ('opposition', array([[-0.74757722]])),
#   ('grant', array([[-0.74823775]])),
#   ('employee', array([[-0.74922081]])),
#   ('prize', array([[-0.75251989]]))],
#  'main': [('desert', array([[-0.71584464]])),
#   ('if', array([[-0.71854547]])),
#   ('trading', array([[-0.73935569]])),
#   ('counter', array([[-0.74244574]])),
#   ('accompany', array([[-0.74357644]])),
#   ('fourth', array([[-0.74586089]])),
#   ('neighbourhood', array([[-0.74683327]])),
#   ('shy', array([[-0.74750546]])),
#   ('harmful', array([[-0.74764845]])),
#   ('statue', array([[-0.74811009]])),
#   ('jelly', array([[-0.74854527]])),
#   ('pleasure', array([[-0.74898157]]))],
#  'owner': [('desert', array([[-0.71958092]])),
#   ('if', array([[-0.73612021]])),
#   ('trading', array([[-0.73976763]])),
#   ('nephew', array([[-0.7452309]])),
#   ('statue', array([[-0.74547384]])),
#   ('amazed', array([[-0.74746841]])),
#   ('ourselves', array([[-0.74831986]])),
#   ('dominate', array([[-0.74899228]])),
#   ('anything', array([[-0.75090204]])),
#   ('spell', array([[-0.7515651]])),
#   ('origin', array([[-0.75231693]])),
#   ('convenient', array([[-0.75256656]]))],
#  'hero': [('trading', array([[-0.75067743]])),
#   ('nephew', array([[-0.75573785]])),
#   ('if', array([[-0.75806924]])),
#   ('ourselves', array([[-0.76157972]])),
#   ('full', array([[-0.76954965]])),
#   ('counter', array([[-0.77050606]])),
#   ('smoothly', array([[-0.77210548]])),
#   ('desert', array([[-0.7724723]])),
#   ('himself', array([[-0.77260275]])),
#   ('fourth', array([[-0.77320333]])),
#   ('jelly', array([[-0.77396424]])),
#   ('complicated', array([[-0.77511941]]))],
#  'breakfast': [('desert', array([[-0.69663356]])),
#   ('origin', array([[-0.70796393]])),
#   ('attraction', array([[-0.71003579]])),
#   ('if', array([[-0.71029848]])),
#   ('steadily', array([[-0.71436089]])),
#   ('moment', array([[-0.7151113]])),
#   ('nephew', array([[-0.71515784]])),
#   ('complicated', array([[-0.71929344]])),
#   ('hire', array([[-0.72304789]])),
#   ('smoothly', array([[-0.72410509]])),
#   ('grant', array([[-0.72453615]])),
#   ('rank', array([[-0.72632682]]))],
#  'depend': [('trading', array([[-0.75926049]])),
#   ('amazed', array([[-0.76051852]])),
#   ('desert', array([[-0.76219984]])),
#   ('rank', array([[-0.76383836]])),
#   ('attraction', array([[-0.7667786]])),
#   ('origin', array([[-0.76700791]])),
#   ('smoothly', array([[-0.77047824]])),
#   ('work', array([[-0.7706991]])),
#   ('full', array([[-0.77152606]])),
#   ('board', array([[-0.77262977]])),
#   ('nephew', array([[-0.77322014]])),
#   ('join', array([[-0.7732833]]))],
#  'suddenly': [('desert', array([[-0.73337012]])),
#   ('spell', array([[-0.73915956]])),
#   ('bore', array([[-0.74508069]])),
#   ('again', array([[-0.75060135]])),
#   ('moment', array([[-0.75270886]])),
#   ('here', array([[-0.75391996]])),
#   ('neighbourhood', array([[-0.75425553]])),
#   ('public', array([[-0.7554425]])),
#   ('nicely', array([[-0.75600914]])),
#   ('ruler', array([[-0.75630868]])),
#   ('pace', array([[-0.7570319]])),
#   ('nor', array([[-0.75751763]]))],
#  'visit': [('nephew', array([[-0.73432866]])),
#   ('swearing', array([[-0.74214546]])),
#   ('statue', array([[-0.74217794]])),
#   ('ourselves', array([[-0.74297842]])),
#   ('if', array([[-0.74358637]])),
#   ('lonely', array([[-0.74501885]])),
#   ('trading', array([[-0.74583189]])),
#   ('parent', array([[-0.74861111]])),
#   ('desert', array([[-0.74862567]])),
#   ('anything', array([[-0.74866745]])),
#   ('nicely', array([[-0.7494388]])),
#   ('value', array([[-0.74990412]]))],
#  'benefit': [('desert', array([[-0.72110315]])),
#   ('origin', array([[-0.72864723]])),
#   ('anything', array([[-0.72971942]])),
#   ('amazed', array([[-0.73124825]])),
#   ('himself', array([[-0.73591372]])),
#   ('steadily', array([[-0.73659354]])),
#   ('pale', array([[-0.73678341]])),
#   ('shy', array([[-0.73695236]])),
#   ('protection', array([[-0.73799711]])),
#   ('if', array([[-0.73889631]])),
#   ('such', array([[-0.73906771]])),
#   ('healthy', array([[-0.73934706]]))],
#  'mass': [('if', array([[-0.72041038]])),
#   ('desert', array([[-0.72283192]])),
#   ('smoothly', array([[-0.7283567]])),
#   ('grant', array([[-0.72967931]])),
#   ('cinema', array([[-0.7301851]])),
#   ('work', array([[-0.73054661]])),
#   ('rank', array([[-0.73375832]])),
#   ('statue', array([[-0.7359371]])),
#   ('accompany', array([[-0.73595671]])),
#   ('anything', array([[-0.73772661]])),
#   ('full', array([[-0.73899196]])),
#   ('opposition', array([[-0.74082351]]))],
#  'between': [('if', array([[-0.73252007]])),
#   ('trading', array([[-0.73257784]])),
#   ('desert', array([[-0.7377759]])),
#   ('nephew', array([[-0.74163291]])),
#   ('hire', array([[-0.74206414]])),
#   ('origin', array([[-0.74439317]])),
#   ('nicely', array([[-0.74697204]])),
#   ('healthy', array([[-0.75130274]])),
#   ('neighbourhood', array([[-0.75131291]])),
#   ('attend', array([[-0.75193192]])),
#   ('ourselves', array([[-0.7526975]])),
#   ('often', array([[-0.75363373]]))],
#  'island': [('desert', array([[-0.70149846]])),
#   ('if', array([[-0.70959643]])),
#   ('nephew', array([[-0.7303454]])),
#   ('jelly', array([[-0.73138491]])),
#   ('ourselves', array([[-0.73513047]])),
#   ('neighbourhood', array([[-0.74304191]])),
#   ('swearing', array([[-0.74442109]])),
#   ('nicely', array([[-0.74521354]])),
#   ('lonely', array([[-0.74825565]])),
#   ('origin', array([[-0.74873353]])),
#   ('hire', array([[-0.74945774]])),
#   ('parent', array([[-0.75001401]]))],
#  'particularly': [('protection', array([[-0.73282707]])),
#   ('origin', array([[-0.74031979]])),
#   ('trading', array([[-0.74100005]])),
#   ('existence', array([[-0.7431374]])),
#   ('steadily', array([[-0.74561204]])),
#   ('anything', array([[-0.7534808]])),
#   ('amazed', array([[-0.75352617]])),
#   ('desert', array([[-0.75471653]])),
#   ('hearing', array([[-0.75613389]])),
#   ('bore', array([[-0.75804592]])),
#   ('dominate', array([[-0.75932678]])),
#   ('line', array([[-0.76271937]]))],
#  'import': [('if', array([[-0.71314282]])),
#   ('desert', array([[-0.71596282]])),
#   ('trading', array([[-0.72889544]])),
#   ('nephew', array([[-0.74063452]])),
#   ('counter', array([[-0.74068876]])),
#   ('smoothly', array([[-0.74182812]])),
#   ('steam', array([[-0.74207273]])),
#   ('origin', array([[-0.7423672]])),
#   ('join', array([[-0.7439846]])),
#   ('protection', array([[-0.74540223]])),
#   ('statue', array([[-0.74594731]])),
#   ('ad', array([[-0.74811076]]))],
#  'luggage': [('desert', array([[-0.68648893]])),
#   ('if', array([[-0.70302875]])),
#   ('nephew', array([[-0.71457292]])),
#   ('moment', array([[-0.71856636]])),
#   ('western', array([[-0.72071518]])),
#   ('smoothly', array([[-0.72257791]])),
#   ('steadily', array([[-0.72485166]])),
#   ('origin', array([[-0.72754727]])),
#   ('taste', array([[-0.72776329]])),
#   ('attraction', array([[-0.72858326]])),
#   ('statue', array([[-0.72882499]])),
#   ('hire', array([[-0.72966404]]))],
#  'soup': [('ourselves', array([[-0.73158724]])),
#   ('counter', array([[-0.73267545]])),
#   ('origin', array([[-0.73307994]])),
#   ('nicely', array([[-0.73550343]])),
#   ('if', array([[-0.73560657]])),
#   ('rank', array([[-0.73783605]])),
#   ('nephew', array([[-0.73809656]])),
#   ('jelly', array([[-0.74285785]])),
#   ('cinema', array([[-0.74314044]])),
#   ('trading', array([[-0.74337411]])),
#   ('smoothly', array([[-0.74545449]])),
#   ('attraction', array([[-0.74683171]]))],
#  'move': [('desert', array([[-0.74017037]])),
#   ('if', array([[-0.74149008]])),
#   ('trading', array([[-0.74441453]])),
#   ('nephew', array([[-0.74521414]])),
#   ('statue', array([[-0.75075776]])),
#   ('nicely', array([[-0.76019469]])),
#   ('neighbourhood', array([[-0.76073614]])),
#   ('counter', array([[-0.7613827]])),
#   ('western', array([[-0.76285276]])),
#   ('origin', array([[-0.76412804]])),
#   ('pleasure', array([[-0.76430109]])),
#   ('bandage', array([[-0.76609774]]))],
#  'estimate': [('desert', array([[-0.69751896]])),
#   ('if', array([[-0.70714811]])),
#   ('origin', array([[-0.71424107]])),
#   ('steadily', array([[-0.71668551]])),
#   ('western', array([[-0.72242118]])),
#   ('pale', array([[-0.7263111]])),
#   ('protection', array([[-0.72712789]])),
#   ('complicated', array([[-0.72824533]])),
#   ('healthy', array([[-0.72943627]])),
#   ('amazed', array([[-0.7340957]])),
#   ('taste', array([[-0.73590341]])),
#   ('counter', array([[-0.73603286]]))],
#  'precise': [('healthy', array([[-0.73639626]])),
#   ('amazed', array([[-0.73782571]])),
#   ('desert', array([[-0.73913229]])),
#   ('fortieth', array([[-0.74139822]])),
#   ('origin', array([[-0.74167489]])),
#   ('illustrate', array([[-0.74291327]])),
#   ('if', array([[-0.74297324]])),
#   ('trading', array([[-0.74453375]])),
#   ('major', array([[-0.74608379]])),
#   ('hearing', array([[-0.74690604]])),
#   ('protection', array([[-0.74746597]])),
#   ('anything', array([[-0.74777279]]))],
#  'page': [('if', array([[-0.73331615]])),
#   ('desert', array([[-0.74257352]])),
#   ('trading', array([[-0.75112149]])),
#   ('nephew', array([[-0.7541252]])),
#   ('anything', array([[-0.75835794]])),
#   ('ourselves', array([[-0.75850506]])),
#   ('nicely', array([[-0.7610057]])),
#   ('counter', array([[-0.76183664]])),
#   ('statue', array([[-0.76446088]])),
#   ('hire', array([[-0.76463483]])),
#   ('bandage', array([[-0.76487733]])),
#   ('join', array([[-0.76603463]]))],
#  'factor': [('desert', array([[-0.73416895]])),
#   ('if', array([[-0.74080262]])),
#   ('join', array([[-0.74378349]])),
#   ('trading', array([[-0.74742647]])),
#   ('complicated', array([[-0.74784876]])),
#   ('cinema', array([[-0.7494673]])),
#   ('rank', array([[-0.75029548]])),
#   ('origin', array([[-0.750745]])),
#   ('protection', array([[-0.75428883]])),
#   ('spell', array([[-0.75533683]])),
#   ('parent', array([[-0.75656704]])),
#   ('hire', array([[-0.75722184]]))],
#  'frightened': [('nephew', array([[-0.71544446]])),
#   ('moment', array([[-0.72765331]])),
#   ('full', array([[-0.73676707]])),
#   ('rank', array([[-0.7377676]])),
#   ('yes', array([[-0.73977747]])),
#   ('desert', array([[-0.74123608]])),
#   ('hire', array([[-0.7446313]])),
#   ('popular', array([[-0.74491853]])),
#   ('impact', array([[-0.74525898]])),
#   ('prefer', array([[-0.74777302]])),
#   ('cinema', array([[-0.74823011]])),
#   ('here', array([[-0.74869966]]))],
#  'pose': [('if', array([[-0.75619082]])),
#   ('origin', array([[-0.75704153]])),
#   ('trading', array([[-0.76059569]])),
#   ('ourselves', array([[-0.76376157]])),
#   ('desert', array([[-0.76614259]])),
#   ('attend', array([[-0.76703504]])),
#   ('nicely', array([[-0.7688971]])),
#   ('lonely', array([[-0.76921064]])),
#   ('pleasure', array([[-0.76972536]])),
#   ('statue', array([[-0.77041817]])),
#   ('counter', array([[-0.77077938]])),
#   ('ad', array([[-0.77283931]]))],
#  'machinery': [('desert', array([[-0.7057497]])),
#   ('origin', array([[-0.71048499]])),
#   ('smoothly', array([[-0.7150034]])),
#   ('if', array([[-0.71950249]])),
#   ('steadily', array([[-0.72203271]])),
#   ('taste', array([[-0.72337262]])),
#   ('nephew', array([[-0.7272081]])),
#   ('full', array([[-0.72755921]])),
#   ('convenient', array([[-0.72940605]])),
#   ('statue', array([[-0.73065578]])),
#   ('dominate', array([[-0.7321866]])),
#   ('spell', array([[-0.73346451]]))],
#  'new': [('if', array([[-0.72655898]])),
#   ('desert', array([[-0.73205428]])),
#   ('trading', array([[-0.7349854]])),
#   ('neighbourhood', array([[-0.73638581]])),
#   ('nephew', array([[-0.74119623]])),
#   ('anything', array([[-0.7413121]])),
#   ('attend', array([[-0.74646861]])),
#   ('swearing', array([[-0.74707831]])),
#   ('spell', array([[-0.74859917]])),
#   ('silent', array([[-0.74923614]])),
#   ('fourth', array([[-0.75001725]])),
#   ('public', array([[-0.75038514]]))],
#  'tradition': [('amazed', array([[-0.71657829]])),
#   ('nephew', array([[-0.72614613]])),
#   ('moment', array([[-0.72791729]])),
#   ('pleasantly', array([[-0.73561021]])),
#   ('steadily', array([[-0.73849896]])),
#   ('pale', array([[-0.73898868]])),
#   ('ourselves', array([[-0.73936238]])),
#   ('existence', array([[-0.73963669]])),
#   ('convenient', array([[-0.74126242]])),
#   ('attraction', array([[-0.74174468]])),
#   ('Monday', array([[-0.74233096]])),
#   ('gain', array([[-0.74455882]]))],
#  'actually': [('anything', array([[-0.75277646]])),
#   ('spell', array([[-0.75546568]])),
#   ('value', array([[-0.76025813]])),
#   ('bandage', array([[-0.7660834]])),
#   ('thousand', array([[-0.7668411]])),
#   ('line', array([[-0.77066492]])),
#   ('moment', array([[-0.77166845]])),
#   ('nicely', array([[-0.77324857]])),
#   ('convenient', array([[-0.77342545]])),
#   ('work', array([[-0.77365767]])),
#   ('trading', array([[-0.7739426]])),
#   ('smoothly', array([[-0.77447269]]))],
#  'kitten': [('nephew', array([[-0.71176091]])),
#   ('ourselves', array([[-0.71479787]])),
#   ('jelly', array([[-0.7204623]])),
#   ('if', array([[-0.72059815]])),
#   ('nicely', array([[-0.72243918]])),
#   ('full', array([[-0.72269611]])),
#   ('desert', array([[-0.72529216]])),
#   ('public', array([[-0.72749664]])),
#   ('join', array([[-0.72921624]])),
#   ('origin', array([[-0.7330982]])),
#   ('hire', array([[-0.73475171]])),
#   ('trading', array([[-0.73500632]]))],
#  'simply': [('desert', array([[-0.73987087]])),
#   ('moment', array([[-0.76234053]])),
#   ('thousand', array([[-0.76247312]])),
#   ('spell', array([[-0.76253556]])),
#   ('anything', array([[-0.76289008]])),
#   ('full', array([[-0.76859293]])),
#   ('cotton', array([[-0.77556697]])),
#   ('value', array([[-0.77562672]])),
#   ('ourselves', array([[-0.77611588]])),
#   ('yes', array([[-0.77819194]])),
#   ('here', array([[-0.77914059]])),
#   ('bandage', array([[-0.77962269]]))],
#  'facility': [('desert', array([[-0.7017651]])),
#   ('origin', array([[-0.72541854]])),
#   ('if', array([[-0.73247339]])),
#   ('trading', array([[-0.73465022]])),
#   ('spell', array([[-0.73548537]])),
#   ('steadily', array([[-0.73575479]])),
#   ('healthy', array([[-0.73709663]])),
#   ('nephew', array([[-0.73765238]])),
#   ('complicated', array([[-0.73860504]])),
#   ('amazed', array([[-0.74179415]])),
#   ('protection', array([[-0.74215327]])),
#   ('statue', array([[-0.74215578]]))],
#  'away': [('nephew', array([[-0.70112047]])),
#   ('desert', array([[-0.71109063]])),
#   ('if', array([[-0.72543248]])),
#   ('swearing', array([[-0.72567776]])),
#   ('hire', array([[-0.72748262]])),
#   ('nicely', array([[-0.73139516]])),
#   ('ourselves', array([[-0.73517114]])),
#   ('such', array([[-0.73631684]])),
#   ('anxious', array([[-0.7384692]])),
#   ('value', array([[-0.73937991]])),
#   ('join', array([[-0.74418878]])),
#   ('public', array([[-0.74420317]]))],
#  'online': [('trading', array([[-0.74047466]])),
#   ('anything', array([[-0.74212578]])),
#   ('full', array([[-0.74330432]])),
#   ('desert', array([[-0.74682609]])),
#   ('if', array([[-0.74935241]])),
#   ('value', array([[-0.74961976]])),
#   ('statue', array([[-0.75134339]])),
#   ('nephew', array([[-0.75160687]])),
#   ('nicely', array([[-0.75375653]])),
#   ('complicated', array([[-0.75413348]])),
#   ('counter', array([[-0.75434893]])),
#   ('swearing', array([[-0.7574229]]))],
#  'o’clock': [('desert', array([[-0.70534621]])),
#   ('if', array([[-0.70853333]])),
#   ('nephew', array([[-0.71453207]])),
#   ('attraction', array([[-0.72383665]])),
#   ('rank', array([[-0.72857116]])),
#   ('anything', array([[-0.73037644]])),
#   ('again', array([[-0.73044576]])),
#   ('hire', array([[-0.73563343]])),
#   ('cinema', array([[-0.73605894]])),
#   ('smoothly', array([[-0.73720787]])),
#   ('lonely', array([[-0.7379156]])),
#   ('rarely', array([[-0.73798372]]))],
#  'electricity': [('desert', array([[-0.70722047]])),
#   ('moment', array([[-0.72700264]])),
#   ('complicated', array([[-0.72791589]])),
#   ('spell', array([[-0.72914426]])),
#   ('work', array([[-0.73036727]])),
#   ('smoothly', array([[-0.73042287]])),
#   ('if', array([[-0.73348787]])),
#   ('full', array([[-0.73357151]])),
#   ('taste', array([[-0.73384905]])),
#   ('steadily', array([[-0.73411198]])),
#   ('convenient', array([[-0.73748013]])),
#   ('rank', array([[-0.73772218]]))],
#  'writing': [('desert', array([[-0.74862633]])),
#   ('nephew', array([[-0.75017759]])),
#   ('if', array([[-0.75777991]])),
#   ('nicely', array([[-0.76218242]])),
#   ('full', array([[-0.76831388]])),
#   ('anything', array([[-0.76880567]])),
#   ('join', array([[-0.77022595]])),
#   ('moment', array([[-0.7704114]])),
#   ('origin', array([[-0.7705228]])),
#   ('hire', array([[-0.77127592]])),
#   ('amazed', array([[-0.77177453]])),
#   ('jelly', array([[-0.77188159]]))],
#  'quote': [('desert', array([[-0.75778458]])),
#   ('anything', array([[-0.76559902]])),
#   ('spell', array([[-0.76586721]])),
#   ('complicated', array([[-0.76658407]])),
#   ('if', array([[-0.76694412]])),
#   ('ourselves', array([[-0.76724009]])),
#   ('bandage', array([[-0.77125527]])),
#   ('unimportant', array([[-0.77271549]])),
#   ('amazed', array([[-0.77479291]])),
#   ('himself', array([[-0.77509734]])),
#   ('healthy', array([[-0.77625983]])),
#   ('action', array([[-0.77633592]]))],
#  'bunch': [('desert', array([[-0.70576142]])),
#   ('if', array([[-0.71332983]])),
#   ('nicely', array([[-0.71647815]])),
#   ('work', array([[-0.72412241]])),
#   ('neighbourhood', array([[-0.72527178]])),
#   ('grant', array([[-0.72618958]])),
#   ('anything', array([[-0.72891573]])),
#   ('full', array([[-0.72916194]])),
#   ('society', array([[-0.72939614]])),
#   ('lonely', array([[-0.73024725]])),
#   ('bandage', array([[-0.73185374]])),
#   ('smoothly', array([[-0.73312811]]))],
#  'devote': [('trading', array([[-0.73130787]])),
#   ('nephew', array([[-0.73742983]])),
#   ('statue', array([[-0.75010715]])),
#   ('accompany', array([[-0.75359763]])),
#   ('work', array([[-0.75383062]])),
#   ('anything', array([[-0.75454317]])),
#   ('pale', array([[-0.75457546]])),
#   ('grant', array([[-0.75479304]])),
#   ('cinema', array([[-0.75532889]])),
#   ('Monday', array([[-0.75678259]])),
#   ('smoothly', array([[-0.75739987]])),
#   ('fourth', array([[-0.75799363]]))],
#  'fever': [('smoothly', array([[-0.73242101]])),
#   ('cinema', array([[-0.73586548]])),
#   ('nephew', array([[-0.73587688]])),
#   ('rank', array([[-0.73605466]])),
#   ('full', array([[-0.73671364]])),
#   ('hire', array([[-0.73922689]])),
#   ('trading', array([[-0.73969281]])),
#   ('if', array([[-0.74027373]])),
#   ('join', array([[-0.74090879]])),
#   ('nicely', array([[-0.74421051]])),
#   ('jelly', array([[-0.74558046]])),
#   ('desert', array([[-0.74690346]]))],
#  'arrangement': [('steadily', array([[-0.74188527]])),
#   ('desert', array([[-0.74211165]])),
#   ('moment', array([[-0.74458854]])),
#   ('attraction', array([[-0.74534154]])),
#   ('origin', array([[-0.74604188]])),
#   ('convenient', array([[-0.7554806]])),
#   ('if', array([[-0.75559355]])),
#   ('rarely', array([[-0.75564377]])),
#   ('spell', array([[-0.7580845]])),
#   ('complicated', array([[-0.75819786]])),
#   ('taste', array([[-0.75962533]])),
#   ('amazed', array([[-0.76007806]]))],
#  'practical': [('amazed', array([[-0.72756388]])),
#   ('desert', array([[-0.73271814]])),
#   ('fourth', array([[-0.73322758]])),
#   ('origin', array([[-0.73499067]])),
#   ('full', array([[-0.73623266]])),
#   ('fortieth', array([[-0.73705125]])),
#   ('steadily', array([[-0.73886701]])),
#   ('anything', array([[-0.73991528]])),
#   ('if', array([[-0.74041953]])),
#   ('complicated', array([[-0.74482767]])),
#   ('grab', array([[-0.74496449]])),
#   ('healthy', array([[-0.74526717]]))],
#  'justify': [('complicated', array([[-0.69942943]])),
#   ('ourselves', array([[-0.704326]])),
#   ('existence', array([[-0.71270059]])),
#   ('full', array([[-0.71309173]])),
#   ('amazed', array([[-0.71433425]])),
#   ('mystery', array([[-0.71502147]])),
#   ('convenient', array([[-0.71524045]])),
#   ('conventional', array([[-0.71673026]])),
#   ('moment', array([[-0.71746633]])),
#   ('anyone', array([[-0.71830942]])),
#   ('fortieth', array([[-0.71839243]])),
#   ('harmful', array([[-0.71849129]]))],
#  'repeat': [('smoothly', array([[-0.7250003]])),
#   ('convenient', array([[-0.72914663]])),
#   ('steam', array([[-0.73102302]])),
#   ('jelly', array([[-0.73309343]])),
#   ('rank', array([[-0.73411615]])),
#   ('work', array([[-0.73457872]])),
#   ('moment', array([[-0.73719777]])),
#   ('full', array([[-0.73843569]])),
#   ('steel', array([[-0.73883546]])),
#   ('if', array([[-0.74009431]])),
#   ('desert', array([[-0.74070812]])),
#   ('amazed', array([[-0.74101342]]))],
#  'comfortable': [('trading', array([[-0.72874678]])),
#   ('fourth', array([[-0.73398135]])),
#   ('origin', array([[-0.73483417]])),
#   ('subject', array([[-0.73889726]])),
#   ('desert', array([[-0.73925084]])),
#   ('steadily', array([[-0.74232711]])),
#   ('moment', array([[-0.742575]])),
#   ('delight', array([[-0.7428371]])),
#   ('pleasure', array([[-0.74439896]])),
#   ('full', array([[-0.74516497]])),
#   ('nicely', array([[-0.74867593]])),
#   ('complicated', array([[-0.74925476]]))],
#  'concrete': [('desert', array([[-0.71635261]])),
#   ('if', array([[-0.7235394]])),
#   ('work', array([[-0.72831753]])),
#   ('smoothly', array([[-0.72835785]])),
#   ('convenient', array([[-0.73076289]])),
#   ('grant', array([[-0.73458818]])),
#   ('nephew', array([[-0.73533199]])),
#   ('amazed', array([[-0.73697826]])),
#   ('complicated', array([[-0.74072806]])),
#   ('lonely', array([[-0.74085977]])),
#   ('spell', array([[-0.74149137]])),
#   ('moment', array([[-0.74173499]]))],
#  'quantity': [('desert', array([[-0.70222463]])),
#   ('if', array([[-0.71494849]])),
#   ('smoothly', array([[-0.71654281]])),
#   ('full', array([[-0.72406229]])),
#   ('work', array([[-0.7272233]])),
#   ('complicated', array([[-0.7277071]])),
#   ('sentence', array([[-0.73033843]])),
#   ('steadily', array([[-0.7324695]])),
#   ('dominate', array([[-0.73268572]])),
#   ('origin', array([[-0.73317447]])),
#   ('grant', array([[-0.73425495]])),
#   ('within', array([[-0.7344394]]))],
#  'regional': [('desert', array([[-0.70362479]])),
#   ('if', array([[-0.71006485]])),
#   ('origin', array([[-0.71233835]])),
#   ('trading', array([[-0.71360805]])),
#   ('nephew', array([[-0.71742692]])),
#   ('protection', array([[-0.72044086]])),
#   ('neighbourhood', array([[-0.72964157]])),
#   ('hire', array([[-0.73012019]])),
#   ('pale', array([[-0.73101057]])),
#   ('existence', array([[-0.73296903]])),
#   ('counter', array([[-0.73326198]])),
#   ('pleasantly', array([[-0.73465618]]))],
#  'could': [('desert', array([[-0.72297127]])),
#   ('if', array([[-0.72466582]])),
#   ('trading', array([[-0.73315546]])),
#   ('neighbourhood', array([[-0.73323286]])),
#   ('nicely', array([[-0.74673838]])),
#   ('parent', array([[-0.74802462]])),
#   ('ourselves', array([[-0.74834858]])),
#   ('ad', array([[-0.75143637]])),
#   ('origin', array([[-0.75269706]])),
#   ('counter', array([[-0.75418375]])),
#   ('statue', array([[-0.75574332]])),
#   ('amazed', array([[-0.75575111]]))],
#  'colt': [('if', array([[-0.70618951]])),
#   ('desert', array([[-0.71222884]])),
#   ('trading', array([[-0.71364236]])),
#   ('nephew', array([[-0.71896943]])),
#   ('attend', array([[-0.72042756]])),
#   ('nicely', array([[-0.72838775]])),
#   ('amazed', array([[-0.72930385]])),
#   ('hire', array([[-0.7297247]])),
#   ('attraction', array([[-0.73064967]])),
#   ('counter', array([[-0.7321247]])),
#   ('ourselves', array([[-0.73228872]])),
#   ('swearing', array([[-0.73246123]]))],
#  'launch': [('desert', array([[-0.72667437]])),
#   ('spell', array([[-0.73028087]])),
#   ('if', array([[-0.73299056]])),
#   ('nephew', array([[-0.7407765]])),
#   ('complicated', array([[-0.74279381]])),
#   ('jelly', array([[-0.74332035]])),
#   ('smoothly', array([[-0.74408241]])),
#   ('full', array([[-0.74588621]])),
#   ('ourselves', array([[-0.74701066]])),
#   ('parent', array([[-0.75028731]])),
#   ('anything', array([[-0.75044159]])),
#   ('counter', array([[-0.75207314]]))],
#  'understanding': [('steadily', array([[-0.73577786]])),
#   ('pale', array([[-0.74009535]])),
#   ('origin', array([[-0.74251326]])),
#   ('trading', array([[-0.74952739]])),
#   ('moment', array([[-0.750299]])),
#   ('gold', array([[-0.75035654]])),
#   ('full', array([[-0.75272455]])),
#   ('thousand', array([[-0.75413782]])),
#   ('delight', array([[-0.75604332]])),
#   ('most', array([[-0.75668333]])),
#   ('attraction', array([[-0.75673608]])),
#   ('complicated', array([[-0.75713258]]))],
#  'west': [('desert', array([[-0.69897653]])),
#   ('if', array([[-0.7029957]])),
#   ('trading', array([[-0.71290206]])),
#   ('counter', array([[-0.72792187]])),
#   ('neighbourhood', array([[-0.73431936]])),
#   ('amazed', array([[-0.73456663]])),
#   ('attend', array([[-0.73809794]])),
#   ('origin', array([[-0.74058895]])),
#   ('nephew', array([[-0.74255933]])),
#   ('protection', array([[-0.74541788]])),
#   ('pleasure', array([[-0.74561443]])),
#   ('anything', array([[-0.7460793]]))],
#  'licence': [('desert', array([[-0.7157015]])),
#   ('if', array([[-0.72706541]])),
#   ('amazed', array([[-0.74636575]])),
#   ('healthy', array([[-0.75015333]])),
#   ('origin', array([[-0.7501699]])),
#   ('complicated', array([[-0.75306093]])),
#   ('ourselves', array([[-0.75496695]])),
#   ('trading', array([[-0.75604894]])),
#   ('neighbourhood', array([[-0.7565795]])),
#   ('protection', array([[-0.75709889]])),
#   ('dominate', array([[-0.75740965]])),
#   ('spell', array([[-0.75788347]]))],
#  'while': [('trading', array([[-0.68981768]])),
#   ('hire', array([[-0.71311798]])),
#   ('bandage', array([[-0.71376758]])),
#   ('value', array([[-0.71404587]])),
#   ('swearing', array([[-0.71531794]])),
#   ('rubbish', array([[-0.71718571]])),
#   ('confined', array([[-0.71742153]])),
#   ('library', array([[-0.71744886]])),
#   ('pleasantly', array([[-0.7177367]])),
#   ('important', array([[-0.71850671]])),
#   ('cycle', array([[-0.72123077]])),
#   ('explode', array([[-0.72252806]]))],
#  'ugly': [('nephew', array([[-0.70175903]])),
#   ('if', array([[-0.70225719]])),
#   ('hire', array([[-0.70342505]])),
#   ('desert', array([[-0.7072562]])),
#   ('nicely', array([[-0.71109574]])),
#   ('neighbourhood', array([[-0.72121914]])),
#   ('join', array([[-0.72549739]])),
#   ('lonely', array([[-0.72602427]])),
#   ('society', array([[-0.7287299]])),
#   ('steam', array([[-0.72878436]])),
#   ('pick', array([[-0.72981345]])),
#   ('string', array([[-0.73010349]]))],
#  'non-': [('nephew', array([[-0.70666214]])),
#   ('ourselves', array([[-0.70935789]])),
#   ('desert', array([[-0.71531417]])),
#   ('nicely', array([[-0.71558513]])),
#   ('if', array([[-0.72324562]])),
#   ('unimportant', array([[-0.72853412]])),
#   ('jelly', array([[-0.72876187]])),
#   ('value', array([[-0.73104089]])),
#   ('hire', array([[-0.73386442]])),
#   ('bandage', array([[-0.7409392]])),
#   ('join', array([[-0.74156188]])),
#   ('lonely', array([[-0.744343]]))],
#  'wealth': [('desert', array([[-0.72937327]])),
#   ('if', array([[-0.73995312]])),
#   ('anything', array([[-0.74499509]])),
#   ('origin', array([[-0.74615948]])),
#   ('convenient', array([[-0.74823925]])),
#   ('spell', array([[-0.75067874]])),
#   ('employee', array([[-0.75251932]])),
#   ('amazed', array([[-0.75300674]])),
#   ('smoothly', array([[-0.75419883]])),
#   ('dominate', array([[-0.75492323]])),
#   ('fourth', array([[-0.7555228]])),
#   ('complicated', array([[-0.75563078]]))],
#  'ensure': [('spell', array([[-0.71671343]])),
#   ('convenient', array([[-0.72365254]])),
#   ('period', array([[-0.72573346]])),
#   ('amazed', array([[-0.72718866]])),
#   ('smoothly', array([[-0.72889282]])),
#   ('statue', array([[-0.73050085]])),
#   ('pleasure', array([[-0.73245843]])),
#   ('again', array([[-0.73266401]])),
#   ('trading', array([[-0.73348097]])),
#   ('thousand', array([[-0.73661075]])),
#   ('fourth', array([[-0.73669972]])),
#   ('protection', array([[-0.73843241]]))],
#  'yard': [('if', array([[-0.71300093]])),
#   ('desert', array([[-0.71643856]])),
#   ('nephew', array([[-0.72392733]])),
#   ('origin', array([[-0.73268166]])),
#   ('counter', array([[-0.73621524]])),
#   ('hire', array([[-0.73883028]])),
#   ('statue', array([[-0.74236889]])),
#   ('attraction', array([[-0.74310595]])),
#   ('nicely', array([[-0.74354832]])),
#   ('anything', array([[-0.74490993]])),
#   ('western', array([[-0.7449632]])),
#   ('swearing', array([[-0.74726926]]))],
#  'advertise': [('desert', array([[-0.7135995]])),
#   ('if', array([[-0.71462644]])),
#   ('nephew', array([[-0.724755]])),
#   ('origin', array([[-0.72487123]])),
#   ('steadily', array([[-0.72566018]])),
#   ('spell', array([[-0.73031005]])),
#   ('full', array([[-0.73223154]])),
#   ('shy', array([[-0.7333749]])),
#   ('opposition', array([[-0.73447867]])),
#   ('neighbourhood', array([[-0.73549258]])),
#   ('moment', array([[-0.7357645]])),
#   ('parent', array([[-0.73636825]]))],
#  'disadvantage': [('nephew', array([[-0.69310372]])),
#   ('desert', array([[-0.70026463]])),
#   ('moment', array([[-0.70970363]])),
#   ('seed', array([[-0.7206523]])),
#   ('conclude', array([[-0.72289967]])),
#   ('rank', array([[-0.72346483]])),
#   ('obtain', array([[-0.7239807]])),
#   ('hire', array([[-0.72561281]])),
#   ('if', array([[-0.72631434]])),
#   ('collapse', array([[-0.72657756]])),
#   ('fourteen', array([[-0.7266879]])),
#   ('such', array([[-0.72695213]]))],
#  'small': [('if', array([[-0.67866477]])),
#   ('desert', array([[-0.68710925]])),
#   ('nephew', array([[-0.70697203]])),
#   ('nicely', array([[-0.71679366]])),
#   ('arrest', array([[-0.71755017]])),
#   ('drop', array([[-0.71768679]])),
#   ('amazed', array([[-0.71799667]])),
#   ('under', array([[-0.7215924]])),
#   ('hire', array([[-0.72175298]])),
#   ('ourselves', array([[-0.72193127]])),
#   ('trading', array([[-0.72670256]])),
#   ('promise', array([[-0.72926686]]))],
#  'website': [('desert', array([[-0.73566456]])),
#   ('if', array([[-0.73798879]])),
#   ('nephew', array([[-0.74875763]])),
#   ('smoothly', array([[-0.7523024]])),
#   ('spell', array([[-0.75290517]])),
#   ('join', array([[-0.7531563]])),
#   ('origin', array([[-0.75331671]])),
#   ('statue', array([[-0.75463483]])),
#   ('jelly', array([[-0.75511185]])),
#   ('pale', array([[-0.75601982]])),
#   ('ourselves', array([[-0.75680463]])),
#   ('opposition', array([[-0.75869214]]))],
#  'rice': [('if', array([[-0.7240337]])),
#   ('nephew', array([[-0.72969539]])),
#   ('desert', array([[-0.73942916]])),
#   ('jelly', array([[-0.74199961]])),
#   ('smoothly', array([[-0.74723976]])),
#   ('counter', array([[-0.74755024]])),
#   ('amazed', array([[-0.74862966]])),
#   ('trading', array([[-0.74907332]])),
#   ('rank', array([[-0.74976293]])),
#   ('ourselves', array([[-0.75087353]])),
#   ('hire', array([[-0.75415991]])),
#   ('nicely', array([[-0.75528768]]))],
#  'attach': [('trading', array([[-0.74234673]])),
#   ('if', array([[-0.74519554]])),
#   ('anything', array([[-0.74580222]])),
#   ('desert', array([[-0.74731326]])),
#   ('statue', array([[-0.7515438]])),
#   ('attraction', array([[-0.75396422]])),
#   ('origin', array([[-0.75478195]])),
#   ('work', array([[-0.75689414]])),
#   ('confined', array([[-0.7646142]])),
#   ('counter', array([[-0.76553447]])),
#   ('ad', array([[-0.76585964]])),
#   ('convenient', array([[-0.76608743]]))],
#  'field': [('if', array([[-0.72485248]])),
#   ('desert', array([[-0.72683767]])),
#   ('trading', array([[-0.73810109]])),
#   ('nephew', array([[-0.74152256]])),
#   ('hire', array([[-0.74445063]])),
#   ('anything', array([[-0.74731388]])),
#   ('origin', array([[-0.7474447]])),
#   ('ourselves', array([[-0.74867096]])),
#   ('jelly', array([[-0.74942562]])),
#   ('attend', array([[-0.75060641]])),
#   ('full', array([[-0.75098375]])),
#   ('counter', array([[-0.75121661]]))],
#  'intended': [('ourselves', array([[-0.73100082]])),
#   ('amazed', array([[-0.73354324]])),
#   ('convenient', array([[-0.73532446]])),
#   ('moment', array([[-0.73685389]])),
#   ('nephew', array([[-0.73812285]])),
#   ('anything', array([[-0.73903904]])),
#   ('steadily', array([[-0.73938188]])),
#   ('origin', array([[-0.74122642]])),
#   ('spell', array([[-0.74167047]])),
#   ('achieve', array([[-0.7420331]])),
#   ('statue', array([[-0.74315915]])),
#   ('desert', array([[-0.74399346]]))],
#  'rubbish': [('desert', array([[-0.68380272]])),
#   ('rank', array([[-0.69696272]])),
#   ('moment', array([[-0.69836713]])),
#   ('hire', array([[-0.69939179]])),
#   ('nephew', array([[-0.70252803]])),
#   ('if', array([[-0.70504595]])),
#   ('popular', array([[-0.70847533]])),
#   ('nicely', array([[-0.71089768]])),
#   ('amazed', array([[-0.71284381]])),
#   ('lonely', array([[-0.71465265]])),
#   ('cinema', array([[-0.716524]])),
#   ('ourselves', array([[-0.71675348]]))],
#  'steer': [('trading', array([[-0.72093008]])),
#   ('desert', array([[-0.72105804]])),
#   ('if', array([[-0.72747729]])),
#   ('origin', array([[-0.73374374]])),
#   ('spell', array([[-0.73935864]])),
#   ('nephew', array([[-0.73942787]])),
#   ('amazed', array([[-0.74012954]])),
#   ('ourselves', array([[-0.74149609]])),
#   ('counter', array([[-0.74248514]])),
#   ('nicely', array([[-0.74271835]])),
#   ('statue', array([[-0.74331539]])),
#   ('protection', array([[-0.74406218]]))],
#  'amazed': [('swearing', array([[-0.67543074]])),
#   ('full', array([[-0.68300986]])),
#   ('Monday', array([[-0.68432807]])),
#   ('convenient', array([[-0.69008671]])),
#   ('activity', array([[-0.69334622]])),
#   ('assist', array([[-0.69517287]])),
#   ('ruler', array([[-0.69642588]])),
#   ('horse', array([[-0.69682207]])),
#   ('here', array([[-0.69850676]])),
#   ('again', array([[-0.69852978]])),
#   ('work', array([[-0.69861262]])),
#   ('public', array([[-0.69889628]]))],
#  'mum': [('if', array([[-0.72172966]])),
#   ('counter', array([[-0.72853674]])),
#   ('smoothly', array([[-0.73136229]])),
#   ('desert', array([[-0.7317777]])),
#   ('ourselves', array([[-0.73290702]])),
#   ('trading', array([[-0.73292186]])),
#   ('nephew', array([[-0.73494074]])),
#   ('grant', array([[-0.73526842]])),
#   ('steel', array([[-0.73712777]])),
#   ('jelly', array([[-0.73902164]])),
#   ('attend', array([[-0.73962842]])),
#   ('nicely', array([[-0.740855]]))],
#  'positive': [('spell', array([[-0.7341219]])),
#   ('statue', array([[-0.73714152]])),
#   ('trading', array([[-0.73838216]])),
#   ('anything', array([[-0.73857645]])),
#   ('desert', array([[-0.73985989]])),
#   ('bore', array([[-0.74873273]])),
#   ('complicated', array([[-0.74883344]])),
#   ('conference', array([[-0.74920299]])),
#   ('healthy', array([[-0.74936067]])),
#   ('shy', array([[-0.74969393]])),
#   ('if', array([[-0.75114634]])),
#   ('full', array([[-0.75145399]]))],
#  'used': [('ourselves', array([[-0.73770123]])),
#   ('trading', array([[-0.73907964]])),
#   ('if', array([[-0.7423077]])),
#   ('nicely', array([[-0.742484]])),
#   ('minority', array([[-0.74447767]])),
#   ('nephew', array([[-0.74483582]])),
#   ('desert', array([[-0.74757842]])),
#   ('anything', array([[-0.74874896]])),
#   ('parent', array([[-0.75074237]])),
#   ('protection', array([[-0.75151315]])),
#   ('counter', array([[-0.7534773]])),
#   ('value', array([[-0.75488826]]))],
#  'fifty': [('desert', array([[-0.69629102]])),
#   ('if', array([[-0.69668972]])),
#   ('hire', array([[-0.70805503]])),
#   ('nephew', array([[-0.71156703]])),
#   ('anything', array([[-0.71999993]])),
#   ('full', array([[-0.72381942]])),
#   ('smoothly', array([[-0.72422006]])),
#   ('trading', array([[-0.72539808]])),
#   ('swearing', array([[-0.72733908]])),
#   ('ourselves', array([[-0.72808055]])),
#   ('origin', array([[-0.72835448]])),
#   ('rank', array([[-0.73019624]]))],
#  'pressure': [('desert', array([[-0.73794219]])),
#   ('smoothly', array([[-0.74509356]])),
#   ('if', array([[-0.74974414]])),
#   ('nephew', array([[-0.76215274]])),
#   ('full', array([[-0.76271583]])),
#   ('trading', array([[-0.76272983]])),
#   ('amazed', array([[-0.76534434]])),
#   ('complicated', array([[-0.76571235]])),
#   ('work', array([[-0.76823458]])),
#   ('rank', array([[-0.76868994]])),
#   ('convenient', array([[-0.76879535]])),
#   ('lonely', array([[-0.7696895]]))],
#  'signal': [('desert', array([[-0.73482556]])),
#   ('spell', array([[-0.73888612]])),
#   ('smoothly', array([[-0.73908634]])),
#   ('nephew', array([[-0.74496826]])),
#   ('full', array([[-0.7457268]])),
#   ('if', array([[-0.74660739]])),
#   ('counter', array([[-0.74715575]])),
#   ('origin', array([[-0.74842734]])),
#   ('amazed', array([[-0.74922159]])),
#   ('ourselves', array([[-0.75077241]])),
#   ('trading', array([[-0.7515481]])),
#   ('neighbourhood', array([[-0.75175277]]))],
#  'afterwards': [('moment', array([[-0.73757903]])),
#   ('existence', array([[-0.74359762]])),
#   ('ourselves', array([[-0.74477278]])),
#   ('convenient', array([[-0.74707225]])),
#   ('steadily', array([[-0.7489782]])),
#   ('prize', array([[-0.74922467]])),
#   ('work', array([[-0.74938856]])),
#   ('taste', array([[-0.75092905]])),
#   ('hire', array([[-0.75117888]])),
#   ('origin', array([[-0.75393689]])),
#   ('complicated', array([[-0.75446093]])),
#   ('trading', array([[-0.75485197]]))],
#  'withdraw': [('nephew', array([[-0.70971211]])),
#   ('amazed', array([[-0.71108226]])),
#   ('join', array([[-0.71119659]])),
#   ('moment', array([[-0.72120625]])),
#   ('nicely', array([[-0.72829342]])),
#   ('often', array([[-0.72969354]])),
#   ('desert', array([[-0.73019859]])),
#   ('ourselves', array([[-0.73105277]])),
#   ('hire', array([[-0.73191542]])),
#   ('amused', array([[-0.7331975]])),
#   ('male', array([[-0.73352523]])),
#   ('planet', array([[-0.73426168]]))],
#  'jealous': [('full', array([[-0.72061907]])),
#   ('existence', array([[-0.72140993]])),
#   ('hire', array([[-0.72295232]])),
#   ('convenient', array([[-0.7262863]])),
#   ('origin', array([[-0.72725828]])),
#   ('moment', array([[-0.73082733]])),
#   ('steam', array([[-0.73134684]])),
#   ('steadily', array([[-0.73193272]])),
#   ('taste', array([[-0.73241598]])),
#   ('nor', array([[-0.73373323]])),
#   ('nephew', array([[-0.73604056]])),
#   ('protection', array([[-0.73621716]]))],
#  'country': [('desert', array([[-0.7330278]])),
#   ('if', array([[-0.74055532]])),
#   ('nephew', array([[-0.75098659]])),
#   ('ourselves', array([[-0.75517397]])),
#   ('origin', array([[-0.75900896]])),
#   ('trading', array([[-0.75936249]])),
#   ('hire', array([[-0.76155451]])),
#   ('amazed', array([[-0.76548488]])),
#   ('rank', array([[-0.76699335]])),
#   ('cinema', array([[-0.76764383]])),
#   ('anything', array([[-0.7711803]])),
#   ('neighbourhood', array([[-0.77203535]]))],
#  'awful': [('nephew', array([[-0.70160615]])),
#   ('cinema', array([[-0.71440961]])),
#   ('join', array([[-0.71570407]])),
#   ('rank', array([[-0.71579768]])),
#   ('often', array([[-0.7168003]])),
#   ('planet', array([[-0.71816238]])),
#   ('public', array([[-0.72468521]])),
#   ('lonely', array([[-0.72546645]])),
#   ('hire', array([[-0.728057]])),
#   ('if', array([[-0.73033105]])),
#   ('pick', array([[-0.73035641]])),
#   ('well', array([[-0.73123002]]))],
#  'independent': [('desert', array([[-0.72939798]])),
#   ('nephew', array([[-0.73756206]])),
#   ('ourselves', array([[-0.7441839]])),
#   ('moment', array([[-0.74559749]])),
#   ('flooded', array([[-0.74971964]])),
#   ('complicated', array([[-0.75411762]])),
#   ('anything', array([[-0.75579279]])),
#   ('restore', array([[-0.75797564]])),
#   ('spell', array([[-0.76042473]])),
#   ('speech', array([[-0.76062303]])),
#   ('so', array([[-0.76136894]])),
#   ('such', array([[-0.76210968]]))],
#  'stick': [('desert', array([[-0.73315855]])),
#   ('if', array([[-0.74050471]])),
#   ('amazed', array([[-0.7513258]])),
#   ('nephew', array([[-0.75200934]])),
#   ('ourselves', array([[-0.7564597]])),
#   ('opposition', array([[-0.7586783]])),
#   ('nicely', array([[-0.75923112]])),
#   ('full', array([[-0.76037195]])),
#   ('jelly', array([[-0.76135993]])),
#   ('join', array([[-0.76327606]])),
#   ('rank', array([[-0.7638721]])),
#   ('sand', array([[-0.76537282]]))],
#  'treat': [('ourselves', array([[-0.72100053]])),
#   ('desert', array([[-0.72757291]])),
#   ('nephew', array([[-0.72798411]])),
#   ('if', array([[-0.72913727]])),
#   ('swearing', array([[-0.73007857]])),
#   ('trading', array([[-0.73148799]])),
#   ('pale', array([[-0.73564972]])),
#   ('anything', array([[-0.73647983]])),
#   ('full', array([[-0.74131716]])),
#   ('statue', array([[-0.74135058]])),
#   ('origin', array([[-0.74275404]])),
#   ('nicely', array([[-0.74348531]]))],
#  'trend': [('if', array([[-0.73885054]])),
#   ('trading', array([[-0.74695718]])),
#   ('desert', array([[-0.74944007]])),
#   ('full', array([[-0.75651303]])),
#   ('hire', array([[-0.75691253]])),
#   ('counter', array([[-0.75867952]])),
#   ('nicely', array([[-0.76166007]])),
#   ('attraction', array([[-0.76292423]])),
#   ('neighbourhood', array([[-0.76451279]])),
#   ('nephew', array([[-0.76473805]])),
#   ('origin', array([[-0.76696185]])),
#   ('anything', array([[-0.76758287]]))],
#  'strategy': [('nephew', array([[-0.73426665]])),
#   ('desert', array([[-0.73625485]])),
#   ('amazed', array([[-0.73777838]])),
#   ('origin', array([[-0.74822649]])),
#   ('if', array([[-0.74831541]])),
#   ('full', array([[-0.74873318]])),
#   ('steadily', array([[-0.75087471]])),
#   ('moment', array([[-0.75524953]])),
#   ('spell', array([[-0.75600517]])),
#   ('complicated', array([[-0.7564739]])),
#   ('pale', array([[-0.75815743]])),
#   ('taste', array([[-0.76116228]]))],
#  'flood': [('smoothly', array([[-0.71319853]])),
#   ('statue', array([[-0.72414082]])),
#   ('full', array([[-0.72822401]])),
#   ('if', array([[-0.72961574]])),
#   ('nephew', array([[-0.73099641]])),
#   ('desert', array([[-0.73235703]])),
#   ('opposition', array([[-0.73261821]])),
#   ('cinema', array([[-0.73328001]])),
#   ('attraction', array([[-0.73365368]])),
#   ('origin', array([[-0.73393421]])),
#   ('counter', array([[-0.73433316]])),
#   ('convenient', array([[-0.73436702]]))],
#  'weekend': [('desert', array([[-0.70387972]])),
#   ('if', array([[-0.71529449]])),
#   ('anything', array([[-0.72072661]])),
#   ('nephew', array([[-0.72283315]])),
#   ('hire', array([[-0.72584526]])),
#   ('origin', array([[-0.7282154]])),
#   ('full', array([[-0.72883597]])),
#   ('nicely', array([[-0.72983129]])),
#   ('attraction', array([[-0.73234291]])),
#   ('value', array([[-0.73238557]])),
#   ('steadily', array([[-0.73481122]])),
#   ('trading', array([[-0.73499664]]))],
#  'addition': [('desert', array([[-0.72351479]])),
#   ('statue', array([[-0.73063076]])),
#   ('if', array([[-0.73314892]])),
#   ('origin', array([[-0.73689173]])),
#   ('convenient', array([[-0.74142698]])),
#   ('spell', array([[-0.74154473]])),
#   ('opposition', array([[-0.74201801]])),
#   ('complicated', array([[-0.74296966]])),
#   ('ad', array([[-0.74297981]])),
#   ('join', array([[-0.74948161]])),
#   ('steadily', array([[-0.75070839]])),
#   ('employee', array([[-0.75120934]]))],
#  'everyone': [('work', array([[-0.72200166]])),
#   ('grant', array([[-0.72784594]])),
#   ('convenient', array([[-0.73142327]])),
#   ('cinema', array([[-0.73175149]])),
#   ('moment', array([[-0.7337573]])),
#   ('full', array([[-0.73799226]])),
#   ('rank', array([[-0.73968256]])),
#   ('employee', array([[-0.74002924]])),
#   ('smoothly', array([[-0.74037575]])),
#   ('anything', array([[-0.74228582]])),
#   ('discovery', array([[-0.74547484]])),
#   ('approval', array([[-0.74643467]]))],
#  'bachelor': [('desert', array([[-0.73224781]])),
#   ('if', array([[-0.7342862]])),
#   ('ourselves', array([[-0.74799867]])),
#   ('nephew', array([[-0.74850622]])),
#   ('join', array([[-0.74963575]])),
#   ('amazed', array([[-0.75570679]])),
#   ('nicely', array([[-0.75743042]])),
#   ('spell', array([[-0.76037652]])),
#   ('moment', array([[-0.76175257]])),
#   ('hire', array([[-0.76308588]])),
#   ('jelly', array([[-0.76360085]])),
#   ('lonely', array([[-0.76379517]]))],
#  'introduction': [('spell', array([[-0.72496401]])),
#   ('nephew', array([[-0.73183017]])),
#   ('steadily', array([[-0.73520664]])),
#   ('complicated', array([[-0.73589592]])),
#   ('origin', array([[-0.73762552]])),
#   ('desert', array([[-0.73806903]])),
#   ('moment', array([[-0.73808696]])),
#   ('lonely', array([[-0.74200326]])),
#   ('if', array([[-0.7457636]])),
#   ('employer', array([[-0.74606607]])),
#   ('western', array([[-0.74879689]])),
#   ('taste', array([[-0.74994415]]))],
#  'abandon': [('nephew', array([[-0.71884126]])),
#   ('nicely', array([[-0.7316345]])),
#   ('rank', array([[-0.73483145]])),
#   ('desert', array([[-0.7382039]])),
#   ('ourselves', array([[-0.73986341]])),
#   ('join', array([[-0.74110214]])),
#   ('cinema', array([[-0.74519897]])),
#   ('moment', array([[-0.74735246]])),
#   ('value', array([[-0.75072738]])),
#   ('often', array([[-0.75092222]])),
#   ('if', array([[-0.75130301]])),
#   ('public', array([[-0.75138224]]))],
#  'exist': [('desert', array([[-0.71767646]])),
#   ('if', array([[-0.74363859]])),
#   ('convenient', array([[-0.75280299]])),
#   ('employee', array([[-0.75480254]])),
#   ('spell', array([[-0.7558274]])),
#   ('generously', array([[-0.75583791]])),
#   ('ourselves', array([[-0.756827]])),
#   ('diet', array([[-0.75697909]])),
#   ('complicated', array([[-0.75923296]])),
#   ('jelly', array([[-0.75994467]])),
#   ('anything', array([[-0.76025786]])),
#   ('statue', array([[-0.76087504]]))],
#  'industrial': [('desert', array([[-0.70796968]])),
#   ('if', array([[-0.71417448]])),
#   ('smoothly', array([[-0.73032348]])),
#   ('amazed', array([[-0.73172558]])),
#   ('nephew', array([[-0.73189575]])),
#   ('hire', array([[-0.7324974]])),
#   ('work', array([[-0.73322381]])),
#   ('origin', array([[-0.73502482]])),
#   ('join', array([[-0.73526181]])),
#   ('anything', array([[-0.73696721]])),
#   ('convenient', array([[-0.73768266]])),
#   ('grant', array([[-0.73948275]]))],
#  'textman': [('if', array([[-0.73075771]])),
#   ('desert', array([[-0.7341652]])),
#   ('trading', array([[-0.73703962]])),
#   ('nephew', array([[-0.7391894]])),
#   ('ourselves', array([[-0.74029478]])),
#   ('pale', array([[-0.74075231]])),
#   ('shy', array([[-0.74244916]])),
#   ('counter', array([[-0.74347289]])),
#   ('pleasure', array([[-0.74501334]])),
#   ('action', array([[-0.74880893]])),
#   ('thousand', array([[-0.74997006]])),
#   ('anything', array([[-0.75147406]]))],
#  'walking': [('if', array([[-0.746319]])),
#   ('desert', array([[-0.75116494]])),
#   ('ourselves', array([[-0.7516381]])),
#   ('anything', array([[-0.75305333]])),
#   ('rank', array([[-0.75366957]])),
#   ('grant', array([[-0.7565526]])),
#   ('trading', array([[-0.75793847]])),
#   ('cinema', array([[-0.75908222]])),
#   ('accompany', array([[-0.75975971]])),
#   ('origin', array([[-0.759843]])),
#   ('steam', array([[-0.76044693]])),
#   ('fourth', array([[-0.761165]]))],
#  'realize': [('desert', array([[-0.72039781]])),
#   ('nicely', array([[-0.72485638]])),
#   ('nephew', array([[-0.72917292]])),
#   ('full', array([[-0.73591065]])),
#   ('value', array([[-0.73635071]])),
#   ('if', array([[-0.73648336]])),
#   ('origin', array([[-0.74158897]])),
#   ('western', array([[-0.74180763]])),
#   ('hire', array([[-0.74394755]])),
#   ('trading', array([[-0.74490793]])),
#   ('moment', array([[-0.7450419]])),
#   ('careless', array([[-0.74517428]]))],
#  'minority': [('steadily', array([[-0.69899241]])),
#   ('pale', array([[-0.70647227]])),
#   ('steel', array([[-0.70889493]])),
#   ('full', array([[-0.71031092]])),
#   ('convenient', array([[-0.71258764]])),
#   ('origin', array([[-0.71310466]])),
#   ('protection', array([[-0.71424799]])),
#   ('smoothly', array([[-0.71493001]])),
#   ('work', array([[-0.71508753]])),
#   ('attraction', array([[-0.71508786]])),
#   ('trading', array([[-0.71631693]])),
#   ('grant', array([[-0.71636396]]))],
#  'etc.': [('desert', array([[-0.71253368]])),
#   ('nephew', array([[-0.72075464]])),
#   ('moment', array([[-0.72935697]])),
#   ('rank', array([[-0.72971826]])),
#   ('obtain', array([[-0.73012164]])),
#   ('if', array([[-0.73466944]])),
#   ('hire', array([[-0.73975998]])),
#   ('public', array([[-0.74014432]])),
#   ('parent', array([[-0.74280035]])),
#   ('cinema', array([[-0.74327725]])),
#   ('join', array([[-0.74414956]])),
#   ('amazed', array([[-0.74496699]]))],
#  'fishing': [('desert', array([[-0.72873975]])),
#   ('opposition', array([[-0.73731731]])),
#   ('work', array([[-0.73871799]])),
# ...
#  'lean': [('trading', array([[-0.74074939]])),
#   ('desert', array([[-0.746178]])),
#   ('if', array([[-0.74929227]])),
#   ('amazed', array([[-0.75224766]])),
#   ('join', array([[-0.75905883]])),
#   ('smoothly', array([[-0.7607965]])),
#   ('origin', array([[-0.76102995]])),
#   ('nephew', array([[-0.76123736]])),
#   ('western', array([[-0.76506834]])),
#   ('pleasure', array([[-0.76520966]])),
#   ('lonely', array([[-0.76528304]])),
#   ('statue', array([[-0.76681623]]))],
#  'abroad': [('trading', array([[-0.73210267]])),
#   ('amazed', array([[-0.73871536]])),
#   ('nephew', array([[-0.73892571]])),
#   ('nicely', array([[-0.74119431]])),
#   ('desert', array([[-0.74335336]])),
#   ('pleasure', array([[-0.74393185]])),
#   ('ourselves', array([[-0.74556368]])),
#   ('value', array([[-0.74722781]])),
#   ('himself', array([[-0.74771931]])),
#   ('hat', array([[-0.74918754]])),
#   ('jelly', array([[-0.75081076]])),
#   ('generously', array([[-0.75155513]]))],
#  'software': [('desert', array([[-0.70770788]])),
#   ('if', array([[-0.71155957]])),
#   ('nephew', array([[-0.71181627]])),
#   ('cinema', array([[-0.71687433]])),
#   ('lonely', array([[-0.72023876]])),
#   ('statue', array([[-0.72309761]])),
#   ('prize', array([[-0.72530536]])),
#   ('hire', array([[-0.72568953]])),
#   ('join', array([[-0.72643457]])),
#   ('steam', array([[-0.72648185]])),
#   ('rank', array([[-0.72698701]])),
#   ('trading', array([[-0.72942772]]))],
#  'promotion': [('desert', array([[-0.73530596]])),
#   ('if', array([[-0.74266933]])),
#   ('origin', array([[-0.74598909]])),
#   ('nephew', array([[-0.74901578]])),
#   ('trading', array([[-0.74996363]])),
#   ('join', array([[-0.75004043]])),
#   ('spell', array([[-0.75506821]])),
#   ('smoothly', array([[-0.75588335]])),
#   ('fourth', array([[-0.75670033]])),
#   ('amazed', array([[-0.75752862]])),
#   ('full', array([[-0.75771284]])),
#   ('counter', array([[-0.76075141]]))],
#  'reading': [('desert', array([[-0.7268428]])),
#   ('complicated', array([[-0.72802104]])),
#   ('if', array([[-0.73025467]])),
#   ('origin', array([[-0.73122619]])),
#   ('spell', array([[-0.73134259]])),
#   ('existence', array([[-0.73686325]])),
#   ('steadily', array([[-0.73721007]])),
#   ('anything', array([[-0.74153969]])),
#   ('convenient', array([[-0.74282041]])),
#   ('line', array([[-0.74340461]])),
#   ('conference', array([[-0.74369972]])),
#   ('statue', array([[-0.74399569]]))],
#  'previously': [('nephew', array([[-0.73778047]])),
#   ('desert', array([[-0.7503434]])),
#   ('hire', array([[-0.75183605]])),
#   ('if', array([[-0.75350527]])),
#   ('attraction', array([[-0.76020094]])),
#   ('origin', array([[-0.7629848]])),
#   ('trading', array([[-0.76330184]])),
#   ('rank', array([[-0.76496514]])),
#   ('value', array([[-0.76680596]])),
#   ('full', array([[-0.76744275]])),
#   ('cinema', array([[-0.7683407]])),
#   ('public', array([[-0.76945218]]))],
#  'why': [('trading', array([[-0.70571705]])),
#   ('nephew', array([[-0.71939731]])),
#   ('amazed', array([[-0.72422702]])),
#   ('steam', array([[-0.72921097]])),
#   ('hire', array([[-0.72925549]])),
#   ('line', array([[-0.73039244]])),
#   ('sand', array([[-0.73155893]])),
#   ('spell', array([[-0.73374183]])),
#   ('desert', array([[-0.73820051]])),
#   ('moment', array([[-0.73877566]])),
#   ('pleasure', array([[-0.73886492]])),
#   ('anything', array([[-0.73938409]]))],
#  'grand': [('ourselves', array([[-0.718701]])),
#   ('parent', array([[-0.7292288]])),
#   ('rank', array([[-0.73085654]])),
#   ('neighbourhood', array([[-0.73203039]])),
#   ('cinema', array([[-0.73720795]])),
#   ('hire', array([[-0.74118174]])),
#   ('grant', array([[-0.74209713]])),
#   ('if', array([[-0.74316633]])),
#   ('sand', array([[-0.74502746]])),
#   ('rectangular', array([[-0.74511856]])),
#   ('pole', array([[-0.74666945]])),
#   ('desert', array([[-0.74733894]]))],
#  'seventeen': [('desert', array([[-0.73953955]])),
#   ('if', array([[-0.74104938]])),
#   ('fourth', array([[-0.74427253]])),
#   ('trading', array([[-0.74772336]])),
#   ('kind', array([[-0.75014166]])),
#   ('convenient', array([[-0.75186234]])),
#   ('nephew', array([[-0.75210374]])),
#   ('cinema', array([[-0.75494236]])),
#   ('statue', array([[-0.75505531]])),
#   ('join', array([[-0.75532553]])),
#   ('conference', array([[-0.75543774]])),
#   ('counter', array([[-0.75580793]]))],
#  'interpretation': [('moment', array([[-0.71238734]])),
#   ('full', array([[-0.7146008]])),
#   ('hire', array([[-0.72557331]])),
#   ('taste', array([[-0.72831947]])),
#   ('spell', array([[-0.72904395]])),
#   ('fourth', array([[-0.72979581]])),
#   ('nicely', array([[-0.73000037]])),
#   ('ourselves', array([[-0.73068195]])),
#   ('steadily', array([[-0.73078769]])),
#   ('accompany', array([[-0.73335425]])),
#   ('origin', array([[-0.73385282]])),
#   ('trading', array([[-0.73454286]]))],
#  'description': [('moment', array([[-0.71799914]])),
#   ('full', array([[-0.71863673]])),
#   ('cinema', array([[-0.72019555]])),
#   ('complicated', array([[-0.72029079]])),
#   ('steadily', array([[-0.72041576]])),
#   ('origin', array([[-0.72223257]])),
#   ('obtain', array([[-0.7286781]])),
#   ('rank', array([[-0.7299751]])),
#   ('convenient', array([[-0.72999886]])),
#   ('parent', array([[-0.73271721]])),
#   ('often', array([[-0.73382918]])),
#   ('attraction', array([[-0.73395986]]))],
#  'rely': [('desert', array([[-0.74456075]])),
#   ('nephew', array([[-0.75004433]])),
#   ('if', array([[-0.75324275]])),
#   ('moment', array([[-0.75622358]])),
#   ('ourselves', array([[-0.76215425]])),
#   ('join', array([[-0.76984765]])),
#   ('anything', array([[-0.77210914]])),
#   ('origin', array([[-0.7721345]])),
#   ('full', array([[-0.77222516]])),
#   ('steam', array([[-0.77248494]])),
#   ('parent', array([[-0.77280088]])),
#   ('cinema', array([[-0.77475089]]))],
#  'uniform': [('smoothly', array([[-0.72287133]])),
#   ('convenient', array([[-0.72399505]])),
#   ('achieve', array([[-0.72721446]])),
#   ('thousand', array([[-0.72726233]])),
#   ('steadily', array([[-0.73088169]])),
#   ('certain', array([[-0.73222915]])),
#   ('protection', array([[-0.73232438]])),
#   ('street', array([[-0.73300606]])),
#   ('existence', array([[-0.73313959]])),
#   ('taste', array([[-0.73340034]])),
#   ('nevertheless', array([[-0.73343637]])),
#   ('steel', array([[-0.73346515]]))],
#  'cookie': [('desert', array([[-0.72292884]])),
#   ('if', array([[-0.74579633]])),
#   ('anything', array([[-0.75001507]])),
#   ('nephew', array([[-0.75068482]])),
#   ('work', array([[-0.75587677]])),
#   ('spell', array([[-0.75658142]])),
#   ('rank', array([[-0.75831043]])),
#   ('jelly', array([[-0.75833371]])),
#   ('moment', array([[-0.75905328]])),
#   ('nicely', array([[-0.75931518]])),
#   ('steam', array([[-0.76143199]])),
#   ('grant', array([[-0.76317867]]))],
#  'encounter': [('nephew', array([[-0.74495352]])),
#   ('desert', array([[-0.7460528]])),
#   ('ourselves', array([[-0.74711133]])),
#   ('if', array([[-0.75220134]])),
#   ('nicely', array([[-0.75634864]])),
#   ('origin', array([[-0.75924117]])),
#   ('smoothly', array([[-0.76042679]])),
#   ('trading', array([[-0.7613126]])),
#   ('full', array([[-0.76145866]])),
#   ('amazed', array([[-0.76298245]])),
#   ('parent', array([[-0.76427429]])),
#   ('counter', array([[-0.76577079]]))],
#  'increasingly': [('desert', array([[-0.7544288]])),
#   ('if', array([[-0.76282036]])),
#   ('spell', array([[-0.76326333]])),
#   ('cinema', array([[-0.76658765]])),
#   ('convenient', array([[-0.76743896]])),
#   ('full', array([[-0.76779618]])),
#   ('steadily', array([[-0.76831673]])),
#   ('rank', array([[-0.76912255]])),
#   ('smoothly', array([[-0.76959605]])),
#   ('nephew', array([[-0.76967322]])),
#   ('trading', array([[-0.77344993]])),
#   ('moment', array([[-0.77426869]]))],
#  'ourselves': [('steadily', array([[-0.65490857]])),
#   ('protection', array([[-0.66333278]])),
#   ('confined', array([[-0.66627998]])),
#   ('existence', array([[-0.66819575]])),
#   ('taste', array([[-0.66882705]])),
#   ('origin', array([[-0.6726839]])),
#   ('rarely', array([[-0.67380079]])),
#   ('trading', array([[-0.68023495]])),
#   ('attraction', array([[-0.68206978]])),
#   ('dominate', array([[-0.68265783]])),
#   ('review', array([[-0.68740631]])),
#   ('smoke', array([[-0.69017278]]))],
#  'define': [('desert', array([[-0.69892781]])),
#   ('steadily', array([[-0.7108187]])),
#   ('taste', array([[-0.71535835]])),
#   ('popular', array([[-0.71936135]])),
#   ('nicely', array([[-0.71950067]])),
#   ('work', array([[-0.71979521]])),
#   ('convenient', array([[-0.71991605]])),
#   ('bore', array([[-0.72023689]])),
#   ('origin', array([[-0.72155657]])),
#   ('flooded', array([[-0.72195625]])),
#   ('spell', array([[-0.72263212]])),
#   ('approval', array([[-0.72275743]]))],
#  'yours': [('desert', array([[-0.74165263]])),
#   ('if', array([[-0.74934919]])),
#   ('spell', array([[-0.76630537]])),
#   ('anything', array([[-0.7744022]])),
#   ('trading', array([[-0.77711229]])),
#   ('ourselves', array([[-0.77748141]])),
#   ('sand', array([[-0.77760339]])),
#   ('amazed', array([[-0.77897869]])),
#   ('neighbourhood', array([[-0.78071833]])),
#   ('period', array([[-0.78115378]])),
#   ('counter', array([[-0.7817929]])),
#   ('complicated', array([[-0.78241488]]))],
#  'breath': [('nicely', array([[-0.73029618]])),
#   ('statue', array([[-0.73467828]])),
#   ('trading', array([[-0.73787757]])),
#   ('ourselves', array([[-0.73892597]])),
#   ('parent', array([[-0.74273853]])),
#   ('desert', array([[-0.74571114]])),
#   ('value', array([[-0.74662371]])),
#   ('dance', array([[-0.74800131]])),
#   ('if', array([[-0.74854583]])),
#   ('jelly', array([[-0.74861212]])),
#   ('swearing', array([[-0.75026782]])),
#   ('smoothly', array([[-0.75110059]]))],
#  'include': [('desert', array([[-0.74368826]])),
#   ('ourselves', array([[-0.74688257]])),
#   ('if', array([[-0.75074969]])),
#   ('nephew', array([[-0.7534517]])),
#   ('full', array([[-0.75479988]])),
#   ('origin', array([[-0.7576465]])),
#   ('nicely', array([[-0.75858371]])),
#   ('complicated', array([[-0.76113466]])),
#   ('fourth', array([[-0.76266924]])),
#   ('jelly', array([[-0.76514831]])),
#   ('moment', array([[-0.76629776]])),
#   ('attend', array([[-0.76640293]]))],
#  'solve': [('desert', array([[-0.72302987]])),
#   ('anything', array([[-0.72367798]])),
#   ('if', array([[-0.72431049]])),
#   ('spell', array([[-0.72551892]])),
#   ('trading', array([[-0.72670095]])),
#   ('parent', array([[-0.72707241]])),
#   ('opposition', array([[-0.72906076]])),
#   ('shy', array([[-0.73299152]])),
#   ('statue', array([[-0.73326281]])),
#   ('amazed', array([[-0.73729634]])),
#   ('origin', array([[-0.73902383]])),
#   ('action', array([[-0.73937263]]))],
#  'strict': [('full', array([[-0.73219956]])),
#   ('desert', array([[-0.73655562]])),
#   ('if', array([[-0.73672993]])),
#   ('smoothly', array([[-0.73831621]])),
#   ('healthy', array([[-0.7423138]])),
#   ('ourselves', array([[-0.74281496]])),
#   ('statue', array([[-0.74329384]])),
#   ('counter', array([[-0.74506031]])),
#   ('origin', array([[-0.74596626]])),
#   ('pleasure', array([[-0.74694531]])),
#   ('harmful', array([[-0.74732016]])),
#   ('pale', array([[-0.74762939]]))],
#  'atmosphere': [('amazed', array([[-0.71644615]])),
#   ('ourselves', array([[-0.72143167]])),
#   ('generously', array([[-0.721614]])),
#   ('intention', array([[-0.72536091]])),
#   ('crowded', array([[-0.72639777]])),
#   ('sand', array([[-0.72746006]])),
#   ('unless', array([[-0.72959837]])),
#   ('hungry', array([[-0.72975447]])),
#   ('obtain', array([[-0.73081409]])),
#   ('diet', array([[-0.73567203]])),
#   ('convenient', array([[-0.7364737]])),
#   ('gain', array([[-0.73902685]]))],
#  'cut': [('desert', array([[-0.72625717]])),
#   ('moment', array([[-0.72910353]])),
#   ('convenient', array([[-0.73991605]])),
#   ('origin', array([[-0.7443045]])),
#   ('nephew', array([[-0.74443147]])),
#   ('if', array([[-0.74539188]])),
#   ('steadily', array([[-0.74620701]])),
#   ('full', array([[-0.74668655]])),
#   ('hire', array([[-0.74721055]])),
#   ('taste', array([[-0.7473705]])),
#   ('complicated', array([[-0.75068229]])),
#   ('join', array([[-0.75218643]]))],
#  'say': [('if', array([[-0.7274298]])),
#   ('trading', array([[-0.73528266]])),
#   ('desert', array([[-0.73539597]])),
#   ('anything', array([[-0.73934617]])),
#   ('amazed', array([[-0.74384222]])),
#   ('nicely', array([[-0.74441123]])),
#   ('unimportant', array([[-0.74608976]])),
#   ('ourselves', array([[-0.74746583]])),
#   ('nephew', array([[-0.7575672]])),
#   ('value', array([[-0.75959255]])),
#   ('counter', array([[-0.76031499]])),
#   ('action', array([[-0.76171863]]))],
#  'wallet': [('neighbourhood', array([[-0.73451173]])),
#   ('ourselves', array([[-0.7351962]])),
#   ('desert', array([[-0.73792695]])),
#   ('if', array([[-0.73864089]])),
#   ('nicely', array([[-0.74130892]])),
#   ('bandage', array([[-0.74200366]])),
#   ('society', array([[-0.74312954]])),
#   ('trading', array([[-0.74501717]])),
#   ('swearing', array([[-0.74649934]])),
#   ('statue', array([[-0.74707599]])),
#   ('full', array([[-0.74754856]])),
#   ('value', array([[-0.74802959]]))],
#  'prevent': [('nephew', array([[-0.7286319]])),
#   ('desert', array([[-0.72867771]])),
#   ('if', array([[-0.73065665]])),
#   ('trading', array([[-0.73966081]])),
#   ('amazed', array([[-0.74821833]])),
#   ('full', array([[-0.74852658]])),
#   ('ourselves', array([[-0.74889819]])),
#   ('fourth', array([[-0.74952579]])),
#   ('join', array([[-0.75030111]])),
#   ('statue', array([[-0.75298881]])),
#   ('origin', array([[-0.75327791]])),
#   ('again', array([[-0.75359177]]))],
#  'photographer': [('nephew', array([[-0.69076345]])),
#   ('desert', array([[-0.70197093]])),
#   ('if', array([[-0.71667805]])),
#   ('amazed', array([[-0.71676319]])),
#   ('ourselves', array([[-0.72069617]])),
#   ('generously', array([[-0.74041821]])),
#   ('journey', array([[-0.74206846]])),
#   ('gold', array([[-0.74286465]])),
#   ('jelly', array([[-0.74375885]])),
#   ('period', array([[-0.74704129]])),
#   ('cardboard', array([[-0.74981827]])),
#   ('such', array([[-0.75012671]]))],
#  'telephone': [('moment', array([[-0.70901431]])),
#   ('desert', array([[-0.71383808]])),
#   ('steadily', array([[-0.71792628]])),
#   ('if', array([[-0.72113353]])),
#   ('nephew', array([[-0.72416898]])),
#   ('taste', array([[-0.72518836]])),
#   ('origin', array([[-0.72753013]])),
#   ('hire', array([[-0.73407954]])),
#   ('western', array([[-0.73481766]])),
#   ('statue', array([[-0.73487777]])),
#   ('full', array([[-0.73583946]])),
#   ('smoothly', array([[-0.73595586]]))],
#  'litre': [('desert', array([[-0.70762726]])),
#   ('nephew', array([[-0.71314724]])),
#   ('rank', array([[-0.72963697]])),
#   ('if', array([[-0.73190532]])),
#   ('smoothly', array([[-0.73694457]])),
#   ('western', array([[-0.73797348]])),
#   ('moment', array([[-0.73849484]])),
#   ('origin', array([[-0.74011533]])),
#   ('again', array([[-0.74031375]])),
#   ('join', array([[-0.74138937]])),
#   ('neighbourhood', array([[-0.7416084]])),
#   ('nicely', array([[-0.74180242]]))],
#  'obviously': [('if', array([[-0.69342743]])),
#   ('counter', array([[-0.70520482]])),
#   ('desert', array([[-0.70726485]])),
#   ('origin', array([[-0.70828884]])),
#   ('trading', array([[-0.71183151]])),
#   ('confined', array([[-0.71805502]])),
#   ('smoothly', array([[-0.7192223]])),
#   ('western', array([[-0.71961885]])),
#   ('nephew', array([[-0.72055696]])),
#   ('steel', array([[-0.7209838]])),
#   ('protection', array([[-0.72114696]])),
#   ('ourselves', array([[-0.72247781]]))],
#  'granddaughter': [('spell', array([[-0.7148957]])),
#   ('convenient', array([[-0.722949]])),
#   ('moment', array([[-0.72939426]])),
#   ('desert', array([[-0.72997458]])),
#   ('anything', array([[-0.73317248]])),
#   ('employee', array([[-0.73525446]])),
#   ('major', array([[-0.73568944]])),
#   ('work', array([[-0.73625151]])),
#   ('within', array([[-0.73783428]])),
#   ('illustrate', array([[-0.7398607]])),
#   ('trading', array([[-0.73995067]])),
#   ('line', array([[-0.74096769]]))],
#  'action': [('moment', array([[-0.69784269]])),
#   ('hire', array([[-0.69803603]])),
#   ('desert', array([[-0.70474801]])),
#   ('nephew', array([[-0.70554613]])),
#   ('public', array([[-0.71225054]])),
#   ('join', array([[-0.71412758]])),
#   ('here', array([[-0.71628269]])),
#   ('origin', array([[-0.71629781]])),
#   ('cinema', array([[-0.71635304]])),
#   ('if', array([[-0.71679876]])),
#   ('steadily', array([[-0.71859606]])),
#   ('ourselves', array([[-0.71883402]]))],
#  ...}

# %%
a, b = "", -np.inf
for word in vocab:
    x = out[word][0][1][0][0]
    if x > b:
        b = x
        a = word
print(a, b)
# Out:
# trading -0.6528102459499042

# %%
most_similar(-np.array(model_ada['protection']).reshape(1, -1), phrase=True)
# Out:
# [('moment', array([[-0.67760979]])),
#  ('nicely', array([[-0.68022783]])),
#  ('public', array([[-0.68539278]])),
#  ('full', array([[-0.68922365]])),
#  ('join', array([[-0.68932917]])),
#  ('criticism', array([[-0.68993263]])),
#  ('rank', array([[-0.69157826]])),
#  ('desert', array([[-0.69966284]])),
#  ('hire', array([[-0.69969428]])),
#  ('position', array([[-0.70003039]]))]
